# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow.keras.utils as ku 
from wordcloud import WordCloud
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %% [markdown]
# # Read Data

# %%
# Reading the text data file
data = open('datasets/english_poem.txt', encoding="utf8").read()

# EDA: Generating WordCloud to visualize
# the text
wordcloud = WordCloud(max_font_size=50,
					max_words=100,
					background_color="black").generate(data)

# Plotting the WordCloud
plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("WordCloud.png")
plt.show()

# %% [markdown]
# # Make Corpus

# %%
# Generating the corpus by 
# splitting the text into lines
corpus = data.lower().split("\n")
print(corpus[:10])
# Out:
# ['stay, i said', 'to the cut flowers.', 'they bowed', 'their heads lower.', 'stay, i said to the spider,', 'who fled.', 'stay, leaf.', 'it reddened,', 'embarrassed for me and itself.', 'stay, i said to my body.']

# %% [markdown]
# # Tokenize

# %%
# Fitting the Tokenizer on the Corpus
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# Vocabulary count of the corpus
total_words = len(tokenizer.word_index)

print("Total Words:", total_words)
# Out:
# Total Words: 3807

# %% [markdown]
# # Vectorize

# %%
# Converting the text into embeddings
input_sequences = []
for line in corpus:
	token_list = tokenizer.texts_to_sequences([line])[0]

	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)

max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences,
										maxlen=max_sequence_len,
										padding='pre'))
predictors, label = input_sequences[:, :-2], input_sequences[:, -2]
label = ku.to_categorical(label, num_classes=total_words+1)

# %% [markdown]
# # Build Model

# %%
# Building a Bi-Directional LSTM Model
model = Sequential()
model.add(Embedding(total_words+1, 100, 
					input_length=max_sequence_len-2))
model.add(Bidirectional(LSTM(150, return_sequences=True)))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(total_words+1/2, activation='relu',
				kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(total_words+1, activation='softmax'))
model.compile(loss='categorical_crossentropy',
			optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 14, 100)           380800
#
#  bidirectional_2 (Bidirecti  (None, 14, 300)           301200
#  onal)
#
#  dropout_2 (Dropout)         (None, 14, 300)           0
#
#  lstm_5 (LSTM)               (None, 100)               160400
#
#  dense_4 (Dense)             (None, 3807)              384507
#
#  dense_5 (Dense)             (None, 3808)              14500864
#
# =================================================================
# Total params: 15727771 (60.00 MB)
# Trainable params: 15727771 (60.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# # Train

# %%
history = model.fit(predictors, label, epochs=150, verbose=1)
# Out:
# Epoch 1/150
# 510/510 [==============================] - 85s 155ms/step - loss: 6.5737 - accuracy: 0.0660
# Epoch 2/150
# 510/510 [==============================] - 77s 151ms/step - loss: 6.1412 - accuracy: 0.0701
# Epoch 3/150
# 510/510 [==============================] - 75s 148ms/step - loss: 5.9795 - accuracy: 0.0714
# Epoch 4/150
# 510/510 [==============================] - 80s 156ms/step - loss: 5.8843 - accuracy: 0.0763
# Epoch 5/150
# 510/510 [==============================] - 83s 162ms/step - loss: 5.8027 - accuracy: 0.0844
# Epoch 6/150
# 510/510 [==============================] - 88s 172ms/step - loss: 5.7141 - accuracy: 0.0883
# Epoch 7/150
# 510/510 [==============================] - 83s 163ms/step - loss: 5.6251 - accuracy: 0.0961
# Epoch 8/150
# 510/510 [==============================] - 81s 159ms/step - loss: 5.5427 - accuracy: 0.1051
# Epoch 9/150
# 510/510 [==============================] - 81s 159ms/step - loss: 5.4618 - accuracy: 0.1127
# Epoch 10/150
# 510/510 [==============================] - 80s 156ms/step - loss: 5.3784 - accuracy: 0.1199
# Epoch 11/150
# 510/510 [==============================] - 78s 153ms/step - loss: 5.3079 - accuracy: 0.1245
# Epoch 12/150
# 510/510 [==============================] - 82s 161ms/step - loss: 5.2406 - accuracy: 0.1267
# Epoch 13/150
# 510/510 [==============================] - 80s 157ms/step - loss: 5.1786 - accuracy: 0.1289
# Epoch 14/150
# 510/510 [==============================] - 84s 164ms/step - loss: 5.1115 - accuracy: 0.1335
# Epoch 15/150
# 510/510 [==============================] - 81s 159ms/step - loss: 5.0551 - accuracy: 0.1380
# Epoch 16/150
# 510/510 [==============================] - 79s 154ms/step - loss: 4.9945 - accuracy: 0.1393
# Epoch 17/150
# 510/510 [==============================] - 79s 155ms/step - loss: 4.9319 - accuracy: 0.1456
# Epoch 18/150
# 510/510 [==============================] - 79s 155ms/step - loss: 4.8748 - accuracy: 0.1454
# Epoch 19/150
# 510/510 [==============================] - 83s 163ms/step - loss: 4.8142 - accuracy: 0.1533
# Epoch 20/150
# 510/510 [==============================] - 82s 160ms/step - loss: 4.7603 - accuracy: 0.1556
# Epoch 21/150
# 510/510 [==============================] - 81s 158ms/step - loss: 4.7004 - accuracy: 0.1594
# Epoch 22/150
# 510/510 [==============================] - 80s 156ms/step - loss: 4.6471 - accuracy: 0.1630
# Epoch 23/150
# 510/510 [==============================] - 80s 156ms/step - loss: 4.5902 - accuracy: 0.1683
# Epoch 24/150
# 510/510 [==============================] - 80s 156ms/step - loss: 4.5364 - accuracy: 0.1722
# Epoch 25/150
# 510/510 [==============================] - 80s 157ms/step - loss: 4.4886 - accuracy: 0.1788
# Epoch 26/150
# 510/510 [==============================] - 80s 158ms/step - loss: 4.4300 - accuracy: 0.1850
# Epoch 27/150
# 510/510 [==============================] - 81s 159ms/step - loss: 4.3736 - accuracy: 0.1881
# Epoch 28/150
# 510/510 [==============================] - 81s 159ms/step - loss: 4.3192 - accuracy: 0.1967
# Epoch 29/150
# 510/510 [==============================] - 80s 158ms/step - loss: 4.2734 - accuracy: 0.2051
# Epoch 30/150
# 510/510 [==============================] - 80s 157ms/step - loss: 4.2153 - accuracy: 0.2097
# Epoch 31/150
# 510/510 [==============================] - 81s 158ms/step - loss: 4.1648 - accuracy: 0.2179
# Epoch 32/150
# 510/510 [==============================] - 80s 158ms/step - loss: 4.1045 - accuracy: 0.2254
# Epoch 33/150
# 510/510 [==============================] - 80s 157ms/step - loss: 4.0582 - accuracy: 0.2315
# Epoch 34/150
# 510/510 [==============================] - 80s 157ms/step - loss: 4.0026 - accuracy: 0.2407
# Epoch 35/150
# 510/510 [==============================] - 80s 157ms/step - loss: 3.9541 - accuracy: 0.2453
# Epoch 36/150
# 510/510 [==============================] - 80s 158ms/step - loss: 3.9094 - accuracy: 0.2533
# Epoch 37/150
# 510/510 [==============================] - 82s 161ms/step - loss: 3.8508 - accuracy: 0.2607
# Epoch 38/150
# 510/510 [==============================] - 81s 159ms/step - loss: 3.8082 - accuracy: 0.2715
# Epoch 39/150
# 510/510 [==============================] - 83s 163ms/step - loss: 3.7569 - accuracy: 0.2803
# Epoch 40/150
# 510/510 [==============================] - 84s 165ms/step - loss: 3.7090 - accuracy: 0.2886
# Epoch 41/150
# 510/510 [==============================] - 83s 163ms/step - loss: 3.6661 - accuracy: 0.2990
# Epoch 42/150
# 510/510 [==============================] - 91s 178ms/step - loss: 3.6214 - accuracy: 0.3079
# Epoch 43/150
# 510/510 [==============================] - 83s 163ms/step - loss: 3.5749 - accuracy: 0.3171
# Epoch 44/150
# 510/510 [==============================] - 90s 176ms/step - loss: 3.5374 - accuracy: 0.3235
# Epoch 45/150
# 510/510 [==============================] - 84s 165ms/step - loss: 3.4927 - accuracy: 0.3325
# Epoch 46/150
# 510/510 [==============================] - 79s 155ms/step - loss: 3.4604 - accuracy: 0.3401
# Epoch 47/150
# 510/510 [==============================] - 84s 166ms/step - loss: 3.4202 - accuracy: 0.3482
# Epoch 48/150
# 510/510 [==============================] - 78s 154ms/step - loss: 3.3771 - accuracy: 0.3572
# Epoch 49/150
# 510/510 [==============================] - 82s 160ms/step - loss: 3.3308 - accuracy: 0.3691
# Epoch 50/150
# 510/510 [==============================] - 81s 159ms/step - loss: 3.3040 - accuracy: 0.3759
# Epoch 51/150
# 510/510 [==============================] - 78s 153ms/step - loss: 3.2617 - accuracy: 0.3812
# Epoch 52/150
# 510/510 [==============================] - 82s 162ms/step - loss: 3.2338 - accuracy: 0.3926
# Epoch 53/150
# 510/510 [==============================] - 85s 166ms/step - loss: 3.2062 - accuracy: 0.3945
# Epoch 54/150
# 510/510 [==============================] - 86s 168ms/step - loss: 3.1663 - accuracy: 0.4054
# Epoch 55/150
# 510/510 [==============================] - 83s 163ms/step - loss: 3.1383 - accuracy: 0.4111
# Epoch 56/150
# 510/510 [==============================] - 84s 164ms/step - loss: 3.1025 - accuracy: 0.4162
# Epoch 57/150
# 510/510 [==============================] - 77s 151ms/step - loss: 3.0752 - accuracy: 0.4239
# Epoch 58/150
# 510/510 [==============================] - 81s 159ms/step - loss: 3.0348 - accuracy: 0.4347
# Epoch 59/150
# 510/510 [==============================] - 82s 161ms/step - loss: 3.0067 - accuracy: 0.4395
# Epoch 60/150
# 510/510 [==============================] - 82s 161ms/step - loss: 2.9824 - accuracy: 0.4476
# Epoch 61/150
# 510/510 [==============================] - 82s 162ms/step - loss: 2.9524 - accuracy: 0.4529
# Epoch 62/150
# 510/510 [==============================] - 84s 164ms/step - loss: 2.9250 - accuracy: 0.4602
# Epoch 63/150
# 510/510 [==============================] - 91s 179ms/step - loss: 2.8939 - accuracy: 0.4663
# Epoch 64/150
# 510/510 [==============================] - 84s 166ms/step - loss: 2.8668 - accuracy: 0.4701
# Epoch 65/150
# 510/510 [==============================] - 82s 161ms/step - loss: 2.8473 - accuracy: 0.4780
# Epoch 66/150
# 510/510 [==============================] - 90s 176ms/step - loss: 2.8175 - accuracy: 0.4816
# Epoch 67/150
# 510/510 [==============================] - 92s 181ms/step - loss: 2.7916 - accuracy: 0.4887
# Epoch 68/150
# 510/510 [==============================] - 87s 170ms/step - loss: 2.7710 - accuracy: 0.4941
# Epoch 69/150
# 510/510 [==============================] - 81s 159ms/step - loss: 2.7484 - accuracy: 0.4981
# Epoch 70/150
# 510/510 [==============================] - 88s 172ms/step - loss: 2.7240 - accuracy: 0.5018
# Epoch 71/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.7039 - accuracy: 0.5087
# Epoch 72/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.6738 - accuracy: 0.5142
# Epoch 73/150
# 510/510 [==============================] - 88s 173ms/step - loss: 2.6552 - accuracy: 0.5181
# Epoch 74/150
# 510/510 [==============================] - 90s 176ms/step - loss: 2.6305 - accuracy: 0.5215
# Epoch 75/150
# 510/510 [==============================] - 92s 181ms/step - loss: 2.6172 - accuracy: 0.5275
# Epoch 76/150
# 510/510 [==============================] - 80s 158ms/step - loss: 2.5955 - accuracy: 0.5315
# Epoch 77/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.5796 - accuracy: 0.5342
# Epoch 78/150
# 510/510 [==============================] - 81s 158ms/step - loss: 2.5619 - accuracy: 0.5368
# Epoch 79/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.5394 - accuracy: 0.5406
# Epoch 80/150
# 510/510 [==============================] - 86s 169ms/step - loss: 2.5317 - accuracy: 0.5421
# Epoch 81/150
# 510/510 [==============================] - 90s 177ms/step - loss: 2.5033 - accuracy: 0.5496
# Epoch 82/150
# 510/510 [==============================] - 87s 170ms/step - loss: 2.4838 - accuracy: 0.5497
# Epoch 83/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.4730 - accuracy: 0.5546
# Epoch 84/150
# 510/510 [==============================] - 87s 170ms/step - loss: 2.4550 - accuracy: 0.5607
# Epoch 85/150
# 510/510 [==============================] - 86s 169ms/step - loss: 2.4451 - accuracy: 0.5594
# Epoch 86/150
# 510/510 [==============================] - 86s 169ms/step - loss: 2.4226 - accuracy: 0.5641
# Epoch 87/150
# 510/510 [==============================] - 84s 165ms/step - loss: 2.4150 - accuracy: 0.5647
# Epoch 88/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.3938 - accuracy: 0.5677
# Epoch 89/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.3827 - accuracy: 0.5690
# Epoch 90/150
# 510/510 [==============================] - 85s 166ms/step - loss: 2.3627 - accuracy: 0.5740
# Epoch 91/150
# 510/510 [==============================] - 86s 169ms/step - loss: 2.3573 - accuracy: 0.5742
# Epoch 92/150
# 510/510 [==============================] - 88s 172ms/step - loss: 2.3363 - accuracy: 0.5773
# Epoch 93/150
# 510/510 [==============================] - 86s 169ms/step - loss: 2.3313 - accuracy: 0.5783
# Epoch 94/150
# 510/510 [==============================] - 85s 166ms/step - loss: 2.3057 - accuracy: 0.5847
# Epoch 95/150
# 510/510 [==============================] - 79s 155ms/step - loss: 2.2916 - accuracy: 0.5892
# Epoch 96/150
# 510/510 [==============================] - 78s 154ms/step - loss: 2.2827 - accuracy: 0.5890
# Epoch 97/150
# 510/510 [==============================] - 78s 153ms/step - loss: 2.2746 - accuracy: 0.5901
# Epoch 98/150
# 510/510 [==============================] - 83s 164ms/step - loss: 2.2582 - accuracy: 0.5925
# Epoch 99/150
# 510/510 [==============================] - 81s 159ms/step - loss: 2.2334 - accuracy: 0.5984
# Epoch 100/150
# 510/510 [==============================] - 81s 158ms/step - loss: 2.2390 - accuracy: 0.5955
# Epoch 101/150
# 510/510 [==============================] - 84s 164ms/step - loss: 2.2289 - accuracy: 0.5965
# Epoch 102/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.2163 - accuracy: 0.5992
# Epoch 103/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.2002 - accuracy: 0.6047
# Epoch 104/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.1820 - accuracy: 0.6089
# Epoch 105/150
# 510/510 [==============================] - 86s 169ms/step - loss: 2.1764 - accuracy: 0.6099
# Epoch 106/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.1688 - accuracy: 0.6077
# Epoch 107/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.1601 - accuracy: 0.6111
# Epoch 108/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.1517 - accuracy: 0.6133
# Epoch 109/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.1413 - accuracy: 0.6132
# Epoch 110/150
# 510/510 [==============================] - 88s 173ms/step - loss: 2.1260 - accuracy: 0.6159
# Epoch 111/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.1126 - accuracy: 0.6192
# Epoch 112/150
# 510/510 [==============================] - 88s 172ms/step - loss: 2.1037 - accuracy: 0.6206
# Epoch 113/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.0992 - accuracy: 0.6225
# Epoch 114/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.0834 - accuracy: 0.6242
# Epoch 115/150
# 510/510 [==============================] - 85s 166ms/step - loss: 2.0793 - accuracy: 0.6233
# Epoch 116/150
# 510/510 [==============================] - 86s 168ms/step - loss: 2.0727 - accuracy: 0.6249
# Epoch 117/150
# 510/510 [==============================] - 87s 170ms/step - loss: 2.0652 - accuracy: 0.6272
# Epoch 118/150
# 510/510 [==============================] - 94s 184ms/step - loss: 2.0613 - accuracy: 0.6260
# Epoch 119/150
# 510/510 [==============================] - 90s 177ms/step - loss: 2.0534 - accuracy: 0.6253
# Epoch 120/150
# 510/510 [==============================] - 90s 176ms/step - loss: 2.0429 - accuracy: 0.6311
# Epoch 121/150
# 510/510 [==============================] - 90s 177ms/step - loss: 2.0387 - accuracy: 0.6288
# Epoch 122/150
# 510/510 [==============================] - 90s 176ms/step - loss: 2.0269 - accuracy: 0.6310
# Epoch 123/150
# 510/510 [==============================] - 85s 166ms/step - loss: 2.0143 - accuracy: 0.6333
# Epoch 124/150
# 510/510 [==============================] - 81s 158ms/step - loss: 2.0033 - accuracy: 0.6350
# Epoch 125/150
# 510/510 [==============================] - 80s 157ms/step - loss: 1.9971 - accuracy: 0.6380
# Epoch 126/150
# 510/510 [==============================] - 84s 164ms/step - loss: 1.9934 - accuracy: 0.6376
# Epoch 127/150
# 510/510 [==============================] - 83s 162ms/step - loss: 1.9850 - accuracy: 0.6405
# Epoch 128/150
# 510/510 [==============================] - 86s 168ms/step - loss: 1.9813 - accuracy: 0.6401
# Epoch 129/150
# 510/510 [==============================] - 86s 169ms/step - loss: 1.9703 - accuracy: 0.6411
# Epoch 130/150
# 510/510 [==============================] - 84s 166ms/step - loss: 1.9623 - accuracy: 0.6428
# Epoch 131/150
# 510/510 [==============================] - 89s 174ms/step - loss: 1.9585 - accuracy: 0.6437
# Epoch 132/150
# 510/510 [==============================] - 85s 166ms/step - loss: 1.9485 - accuracy: 0.6458
# Epoch 133/150
# 510/510 [==============================] - 86s 168ms/step - loss: 1.9423 - accuracy: 0.6467
# Epoch 134/150
# 510/510 [==============================] - 85s 167ms/step - loss: 1.9376 - accuracy: 0.6488
# Epoch 135/150
# 510/510 [==============================] - 86s 168ms/step - loss: 1.9384 - accuracy: 0.6473
# Epoch 136/150
# 510/510 [==============================] - 87s 170ms/step - loss: 1.9240 - accuracy: 0.6464
# Epoch 137/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.9201 - accuracy: 0.6481
# Epoch 138/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.9067 - accuracy: 0.6502
# Epoch 139/150
# 510/510 [==============================] - 83s 163ms/step - loss: 1.9028 - accuracy: 0.6527
# Epoch 140/150
# 510/510 [==============================] - 83s 163ms/step - loss: 1.8964 - accuracy: 0.6564
# Epoch 141/150
# 510/510 [==============================] - 83s 163ms/step - loss: 1.8919 - accuracy: 0.6535
# Epoch 142/150
# 510/510 [==============================] - 83s 164ms/step - loss: 1.8999 - accuracy: 0.6491
# Epoch 143/150
# 510/510 [==============================] - 83s 163ms/step - loss: 1.8783 - accuracy: 0.6558
# Epoch 144/150
# 510/510 [==============================] - 86s 170ms/step - loss: 1.8761 - accuracy: 0.6560
# Epoch 145/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.8734 - accuracy: 0.6562
# Epoch 146/150
# 510/510 [==============================] - 82s 161ms/step - loss: 1.8659 - accuracy: 0.6580
# Epoch 147/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.8642 - accuracy: 0.6580
# Epoch 148/150
# 510/510 [==============================] - 85s 167ms/step - loss: 1.8577 - accuracy: 0.6595
# Epoch 149/150
# 510/510 [==============================] - 83s 163ms/step - loss: 1.8564 - accuracy: 0.6599
# Epoch 150/150
# 510/510 [==============================] - 88s 172ms/step - loss: 1.8441 - accuracy: 0.6611

# %% [markdown]
# # Save

# %%
model.save("english_lstm_2.h5")
# Out:
# c:\Users\Ghost\anaconda3\envs\fuse_machines\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Predict

# %%
model = load_model('english_lstm_2.h5')

# %%
seed_text = "world"
next_words = 15
ouptut_text = ""
 
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences(
        [token_list], maxlen=max_sequence_len-2,
      padding='pre')
    predicted = np.argmax(model.predict(token_list, 
                                        verbose=0), axis=-1)
    output_word = ""
     
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
             
    seed_text += " " + output_word
     
print(seed_text)
# Out:
# world is crazier and more of it than we would sea we can sing that we
