# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow.keras.utils as ku 
from wordcloud import WordCloud
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %% [markdown]
# # Read Data

# %%
# Reading the text data file
data = open('datasets/english_poem.txt', encoding="utf8").read()

# EDA: Generating WordCloud to visualize
# the text
wordcloud = WordCloud(max_font_size=50,
					max_words=100,
					background_color="black").generate(data)

# Plotting the WordCloud
plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("WordCloud.png")
plt.show()

# %% [markdown]
# # Make Corpus

# %%
# Generating the corpus by 
# splitting the text into lines
corpus = data.lower().split("\n")
print(corpus[:10])
# Out:
# ['stay, i said', 'to the cut flowers.', 'they bowed', 'their heads lower.', 'stay, i said to the spider,', 'who fled.', 'stay, leaf.', 'it reddened,', 'embarrassed for me and itself.', 'stay, i said to my body.']

# %% [markdown]
# # Tokenize

# %%
# Fitting the Tokenizer on the Corpus
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# Vocabulary count of the corpus
total_words = len(tokenizer.word_index)

print("Total Words:", total_words)
# Out:
# Total Words: 3807

# %% [markdown]
# # Vectorize

# %%
# Converting the text into embeddings
input_sequences = []
for line in corpus:
	token_list = tokenizer.texts_to_sequences([line])[0]
	# print(token_list)
	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)

max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences,
										maxlen=max_sequence_len,
										padding='pre'))
predictors, label = input_sequences[:, :-1], input_sequences[:, -1]

# %%
label.shape
# Out:
# (16311,)

# %%
label = ku.to_categorical(label, num_classes=total_words+1)

# %%
input_sequences.shape
# Out:
# (16311, 16)

# %%
label.shape
# Out:
# (16311, 3808)

# %%
predictors.shape
# Out:
# (16311, 15)

# %%
total_words
# Out:
# 3807

# %% [markdown]
# # Build Model

# %%
# Building a Bi-Directional LSTM Model
model = Sequential()
model.add(Embedding(total_words+1, 100, 
					input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(150, return_sequences=True)))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(total_words+1/2, activation='relu',
				kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(total_words+1, activation='softmax'))
model.compile(loss='categorical_crossentropy',
			optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 15, 100)           380800
#
#  bidirectional (Bidirection  (None, 15, 300)           301200
#  al)
#
#  dropout (Dropout)           (None, 15, 300)           0
#
#  lstm_1 (LSTM)               (None, 100)               160400
#
#  dense (Dense)               (None, 3807)              384507
#
#  dense_1 (Dense)             (None, 3808)              14500864
#
# =================================================================
# Total params: 15727771 (60.00 MB)
# Trainable params: 15727771 (60.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# # Train

# %%
history = model.fit(predictors, label, epochs=150, verbose=1)
# Out:
# Epoch 1/150
# 510/510 [==============================] - 93s 172ms/step - loss: 6.9471 - accuracy: 0.0605
# Epoch 2/150
# 510/510 [==============================] - 86s 169ms/step - loss: 6.4972 - accuracy: 0.0612
# Epoch 3/150
# 510/510 [==============================] - 84s 165ms/step - loss: 6.3306 - accuracy: 0.0648
# Epoch 4/150
# 510/510 [==============================] - 85s 167ms/step - loss: 6.2071 - accuracy: 0.0712
# Epoch 5/150
# 510/510 [==============================] - 83s 162ms/step - loss: 6.1007 - accuracy: 0.0753
# Epoch 6/150
# 510/510 [==============================] - 82s 161ms/step - loss: 5.9840 - accuracy: 0.0818
# Epoch 7/150
# 510/510 [==============================] - 82s 162ms/step - loss: 5.8575 - accuracy: 0.0890
# Epoch 8/150
# 510/510 [==============================] - 83s 162ms/step - loss: 5.7429 - accuracy: 0.0950
# Epoch 9/150
# 510/510 [==============================] - 84s 164ms/step - loss: 5.6262 - accuracy: 0.1014
# Epoch 10/150
# 510/510 [==============================] - 88s 173ms/step - loss: 5.5175 - accuracy: 0.1072
# Epoch 11/150
# 510/510 [==============================] - 89s 175ms/step - loss: 5.4070 - accuracy: 0.1097
# Epoch 12/150
# 510/510 [==============================] - 89s 174ms/step - loss: 5.2978 - accuracy: 0.1184
# Epoch 13/150
# 510/510 [==============================] - 91s 179ms/step - loss: 5.1940 - accuracy: 0.1212
# Epoch 14/150
# 510/510 [==============================] - 89s 175ms/step - loss: 5.0922 - accuracy: 0.1277
# Epoch 15/150
# 510/510 [==============================] - 93s 182ms/step - loss: 4.9890 - accuracy: 0.1356
# Epoch 16/150
# 510/510 [==============================] - 93s 183ms/step - loss: 4.8823 - accuracy: 0.1454
# Epoch 17/150
# 510/510 [==============================] - 88s 173ms/step - loss: 4.7775 - accuracy: 0.1530
# Epoch 18/150
# 510/510 [==============================] - 88s 173ms/step - loss: 4.7191 - accuracy: 0.1585
# Epoch 19/150
# 510/510 [==============================] - 90s 177ms/step - loss: 4.5710 - accuracy: 0.1704
# Epoch 20/150
# 510/510 [==============================] - 84s 164ms/step - loss: 4.4694 - accuracy: 0.1802
# Epoch 21/150
# 510/510 [==============================] - 90s 176ms/step - loss: 4.3669 - accuracy: 0.1917
# Epoch 22/150
# 510/510 [==============================] - 84s 164ms/step - loss: 4.2559 - accuracy: 0.2024
# Epoch 23/150
# 510/510 [==============================] - 82s 161ms/step - loss: 4.1579 - accuracy: 0.2108
# Epoch 24/150
# 510/510 [==============================] - 85s 166ms/step - loss: 4.0524 - accuracy: 0.2275
# Epoch 25/150
# 510/510 [==============================] - 88s 172ms/step - loss: 3.9578 - accuracy: 0.2379
# Epoch 26/150
# 510/510 [==============================] - 90s 176ms/step - loss: 3.8601 - accuracy: 0.2533
# Epoch 27/150
# 510/510 [==============================] - 88s 173ms/step - loss: 3.7700 - accuracy: 0.2653
# Epoch 28/150
# 510/510 [==============================] - 86s 168ms/step - loss: 3.6771 - accuracy: 0.2812
# Epoch 29/150
# 510/510 [==============================] - 89s 174ms/step - loss: 3.5751 - accuracy: 0.3008
# Epoch 30/150
# 510/510 [==============================] - 87s 170ms/step - loss: 3.4815 - accuracy: 0.3152
# Epoch 31/150
# 510/510 [==============================] - 90s 177ms/step - loss: 3.4025 - accuracy: 0.3319
# Epoch 32/150
# 510/510 [==============================] - 90s 177ms/step - loss: 3.3180 - accuracy: 0.3466
# Epoch 33/150
# 510/510 [==============================] - 85s 167ms/step - loss: 3.2386 - accuracy: 0.3667
# Epoch 34/150
# 510/510 [==============================] - 82s 160ms/step - loss: 3.1567 - accuracy: 0.3858
# Epoch 35/150
# 510/510 [==============================] - 82s 161ms/step - loss: 3.0731 - accuracy: 0.3987
# Epoch 36/150
# 510/510 [==============================] - 82s 161ms/step - loss: 3.0037 - accuracy: 0.4135
# Epoch 37/150
# 510/510 [==============================] - 82s 161ms/step - loss: 2.9312 - accuracy: 0.4277
# Epoch 38/150
# 510/510 [==============================] - 91s 178ms/step - loss: 2.8561 - accuracy: 0.4495
# Epoch 39/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.7872 - accuracy: 0.4602
# Epoch 40/150
# 510/510 [==============================] - 87s 170ms/step - loss: 2.7220 - accuracy: 0.4750
# Epoch 41/150
# 510/510 [==============================] - 88s 173ms/step - loss: 2.6632 - accuracy: 0.4892
# Epoch 42/150
# 510/510 [==============================] - 90s 177ms/step - loss: 2.5932 - accuracy: 0.5044
# Epoch 43/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.5438 - accuracy: 0.5169
# Epoch 44/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.4831 - accuracy: 0.5303
# Epoch 45/150
# 510/510 [==============================] - 92s 181ms/step - loss: 2.4221 - accuracy: 0.5467
# Epoch 46/150
# 510/510 [==============================] - 88s 173ms/step - loss: 2.3775 - accuracy: 0.5550
# Epoch 47/150
# 510/510 [==============================] - 86s 168ms/step - loss: 2.3187 - accuracy: 0.5689
# Epoch 48/150
# 510/510 [==============================] - 85s 167ms/step - loss: 2.2656 - accuracy: 0.5772
# Epoch 49/150
# 510/510 [==============================] - 89s 175ms/step - loss: 2.2304 - accuracy: 0.5871
# Epoch 50/150
# 510/510 [==============================] - 86s 170ms/step - loss: 2.1814 - accuracy: 0.5963
# Epoch 51/150
# 510/510 [==============================] - 90s 177ms/step - loss: 2.1296 - accuracy: 0.6069
# Epoch 52/150
# 510/510 [==============================] - 87s 170ms/step - loss: 2.0837 - accuracy: 0.6207
# Epoch 53/150
# 510/510 [==============================] - 90s 176ms/step - loss: 2.0388 - accuracy: 0.6293
# Epoch 54/150
# 510/510 [==============================] - 87s 171ms/step - loss: 2.0208 - accuracy: 0.6329
# Epoch 55/150
# 510/510 [==============================] - 85s 167ms/step - loss: 1.9765 - accuracy: 0.6439
# Epoch 56/150
# 510/510 [==============================] - 87s 170ms/step - loss: 1.9297 - accuracy: 0.6535
# Epoch 57/150
# 510/510 [==============================] - 89s 175ms/step - loss: 1.9003 - accuracy: 0.6625
# Epoch 58/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.8585 - accuracy: 0.6669
# Epoch 59/150
# 510/510 [==============================] - 94s 184ms/step - loss: 1.8298 - accuracy: 0.6752
# Epoch 60/150
# 510/510 [==============================] - 96s 188ms/step - loss: 1.7944 - accuracy: 0.6830
# Epoch 61/150
# 510/510 [==============================] - 87s 170ms/step - loss: 1.7683 - accuracy: 0.6865
# Epoch 62/150
# 510/510 [==============================] - 84s 166ms/step - loss: 1.7351 - accuracy: 0.6941
# Epoch 63/150
# 510/510 [==============================] - 86s 169ms/step - loss: 1.7045 - accuracy: 0.7015
# Epoch 64/150
# 510/510 [==============================] - 83s 163ms/step - loss: 1.6775 - accuracy: 0.7066
# Epoch 65/150
# 510/510 [==============================] - 96s 187ms/step - loss: 1.6505 - accuracy: 0.7126
# Epoch 66/150
# 510/510 [==============================] - 102s 200ms/step - loss: 1.6162 - accuracy: 0.7190
# Epoch 67/150
# 510/510 [==============================] - 89s 175ms/step - loss: 1.5819 - accuracy: 0.7257
# Epoch 68/150
# 510/510 [==============================] - 87s 170ms/step - loss: 1.5787 - accuracy: 0.7247
# Epoch 69/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.5520 - accuracy: 0.7291
# Epoch 70/150
# 510/510 [==============================] - 88s 172ms/step - loss: 1.5205 - accuracy: 0.7374
# Epoch 71/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.5115 - accuracy: 0.7375
# Epoch 72/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.4816 - accuracy: 0.7431
# Epoch 73/150
# 510/510 [==============================] - 87s 170ms/step - loss: 1.4580 - accuracy: 0.7480
# Epoch 74/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.4364 - accuracy: 0.7527
# Epoch 75/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.4346 - accuracy: 0.7541
# Epoch 76/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.4045 - accuracy: 0.7593
# Epoch 77/150
# 510/510 [==============================] - 84s 166ms/step - loss: 1.3739 - accuracy: 0.7657
# Epoch 78/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.3617 - accuracy: 0.7681
# Epoch 79/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.3550 - accuracy: 0.7689
# Epoch 80/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.3431 - accuracy: 0.7700
# Epoch 81/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.3221 - accuracy: 0.7726
# Epoch 82/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.3076 - accuracy: 0.7749
# Epoch 83/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.2849 - accuracy: 0.7820
# Epoch 84/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.2737 - accuracy: 0.7843
# Epoch 85/150
# 510/510 [==============================] - 92s 180ms/step - loss: 1.2664 - accuracy: 0.7822
# Epoch 86/150
# 510/510 [==============================] - 87s 172ms/step - loss: 1.2431 - accuracy: 0.7870
# Epoch 87/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.2485 - accuracy: 0.7847
# Epoch 88/150
# 510/510 [==============================] - 88s 172ms/step - loss: 1.2227 - accuracy: 0.7935
# Epoch 89/150
# 510/510 [==============================] - 87s 170ms/step - loss: 1.2187 - accuracy: 0.7898
# Epoch 90/150
# 510/510 [==============================] - 88s 173ms/step - loss: 1.2035 - accuracy: 0.7937
# Epoch 91/150
# 510/510 [==============================] - 88s 172ms/step - loss: 1.1842 - accuracy: 0.7964
# Epoch 92/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.1774 - accuracy: 0.7984
# Epoch 93/150
# 510/510 [==============================] - 89s 174ms/step - loss: 1.1619 - accuracy: 0.8023
# Epoch 94/150
# 510/510 [==============================] - 94s 184ms/step - loss: 1.1626 - accuracy: 0.7984
# Epoch 95/150
# 510/510 [==============================] - 103s 202ms/step - loss: 1.1546 - accuracy: 0.8009
# Epoch 96/150
# 510/510 [==============================] - 93s 183ms/step - loss: 1.1249 - accuracy: 0.8060
# Epoch 97/150
# 510/510 [==============================] - 82s 162ms/step - loss: 1.1211 - accuracy: 0.8065
# Epoch 98/150
# 510/510 [==============================] - 87s 171ms/step - loss: 1.1177 - accuracy: 0.8064
# Epoch 99/150
# 510/510 [==============================] - 95s 186ms/step - loss: 1.1106 - accuracy: 0.8099
# Epoch 100/150
# 510/510 [==============================] - 95s 186ms/step - loss: 1.1042 - accuracy: 0.8090
# Epoch 101/150
# 510/510 [==============================] - 115s 226ms/step - loss: 1.0861 - accuracy: 0.8134
# Epoch 102/150
# 510/510 [==============================] - 97s 191ms/step - loss: 1.0918 - accuracy: 0.8110
# Epoch 103/150
# 510/510 [==============================] - 99s 195ms/step - loss: 1.0802 - accuracy: 0.8115
# Epoch 104/150
# 510/510 [==============================] - 99s 195ms/step - loss: 1.0687 - accuracy: 0.8153
# Epoch 105/150
# 510/510 [==============================] - 99s 194ms/step - loss: 1.0616 - accuracy: 0.8149
# Epoch 106/150
# 510/510 [==============================] - 99s 194ms/step - loss: 1.0451 - accuracy: 0.8180
# Epoch 107/150
# 510/510 [==============================] - 95s 185ms/step - loss: 1.0441 - accuracy: 0.8162
# Epoch 108/150
# 510/510 [==============================] - 93s 182ms/step - loss: 1.0437 - accuracy: 0.8187
# Epoch 109/150
# 510/510 [==============================] - 96s 188ms/step - loss: 1.0429 - accuracy: 0.8183
# Epoch 110/150
# 510/510 [==============================] - 99s 195ms/step - loss: 1.0304 - accuracy: 0.8181
# Epoch 111/150
# 510/510 [==============================] - 103s 202ms/step - loss: 1.0390 - accuracy: 0.8142
# Epoch 112/150
# 510/510 [==============================] - 104s 203ms/step - loss: 1.0289 - accuracy: 0.8175
# Epoch 113/150
# 510/510 [==============================] - 92s 181ms/step - loss: 1.0032 - accuracy: 0.8213
# Epoch 114/150
# 510/510 [==============================] - 84s 165ms/step - loss: 1.0010 - accuracy: 0.8246
# Epoch 115/150
# 510/510 [==============================] - 78s 152ms/step - loss: 0.9946 - accuracy: 0.8247
# Epoch 116/150
# 510/510 [==============================] - 85s 167ms/step - loss: 0.9941 - accuracy: 0.8227
# Epoch 117/150
# 510/510 [==============================] - 80s 156ms/step - loss: 0.9974 - accuracy: 0.8213
# Epoch 118/150
# 510/510 [==============================] - 77s 151ms/step - loss: 0.9835 - accuracy: 0.8263
# Epoch 119/150
# 510/510 [==============================] - 81s 159ms/step - loss: 0.9803 - accuracy: 0.8218
# Epoch 120/150
# 510/510 [==============================] - 88s 172ms/step - loss: 0.9611 - accuracy: 0.8281
# Epoch 121/150
# 510/510 [==============================] - 93s 182ms/step - loss: 0.9583 - accuracy: 0.8289
# Epoch 122/150
# 510/510 [==============================] - 78s 152ms/step - loss: 0.9623 - accuracy: 0.8246
# Epoch 123/150
# 510/510 [==============================] - 77s 152ms/step - loss: 0.9609 - accuracy: 0.8236
# Epoch 124/150
# 510/510 [==============================] - 77s 152ms/step - loss: 0.9691 - accuracy: 0.8219
# Epoch 125/150
# 510/510 [==============================] - 84s 164ms/step - loss: 0.9635 - accuracy: 0.8258
# Epoch 126/150
# 510/510 [==============================] - 83s 162ms/step - loss: 0.9428 - accuracy: 0.8268
# Epoch 127/150
# 510/510 [==============================] - 80s 156ms/step - loss: 0.9385 - accuracy: 0.8271
# Epoch 128/150
# 510/510 [==============================] - 80s 157ms/step - loss: 0.9382 - accuracy: 0.8304
# Epoch 129/150
# 510/510 [==============================] - 79s 155ms/step - loss: 0.9312 - accuracy: 0.8283
# Epoch 130/150
# 510/510 [==============================] - 79s 155ms/step - loss: 0.9339 - accuracy: 0.8283
# Epoch 131/150
# 510/510 [==============================] - 79s 155ms/step - loss: 0.9314 - accuracy: 0.8283
# Epoch 132/150
# 510/510 [==============================] - 79s 155ms/step - loss: 0.9194 - accuracy: 0.8280
# Epoch 133/150
# 510/510 [==============================] - 81s 160ms/step - loss: 0.9238 - accuracy: 0.8305
# Epoch 134/150
# 510/510 [==============================] - 81s 159ms/step - loss: 0.9183 - accuracy: 0.8304
# Epoch 135/150
# 510/510 [==============================] - 81s 158ms/step - loss: 0.9106 - accuracy: 0.8327
# Epoch 136/150
# 510/510 [==============================] - 80s 158ms/step - loss: 0.9023 - accuracy: 0.8307
# Epoch 137/150
# 510/510 [==============================] - 81s 158ms/step - loss: 0.9135 - accuracy: 0.8274
# Epoch 138/150
# 510/510 [==============================] - 81s 158ms/step - loss: 0.9123 - accuracy: 0.8299
# Epoch 139/150
# 510/510 [==============================] - 80s 158ms/step - loss: 0.9072 - accuracy: 0.8293
# Epoch 140/150
# 510/510 [==============================] - 81s 158ms/step - loss: 0.8950 - accuracy: 0.8319
# Epoch 141/150
# 510/510 [==============================] - 80s 157ms/step - loss: 0.8860 - accuracy: 0.8350
# Epoch 142/150
# 510/510 [==============================] - 81s 159ms/step - loss: 0.8862 - accuracy: 0.8336
# Epoch 143/150
# 510/510 [==============================] - 87s 171ms/step - loss: 0.8893 - accuracy: 0.8318
# Epoch 144/150
# 510/510 [==============================] - 91s 179ms/step - loss: 0.9013 - accuracy: 0.8289
# Epoch 145/150
# 510/510 [==============================] - 83s 163ms/step - loss: 0.8919 - accuracy: 0.8304
# Epoch 146/150
# 510/510 [==============================] - 80s 157ms/step - loss: 0.8789 - accuracy: 0.8335
# Epoch 147/150
# 510/510 [==============================] - 80s 157ms/step - loss: 0.8668 - accuracy: 0.8358
# Epoch 148/150
# 510/510 [==============================] - 80s 157ms/step - loss: 0.8744 - accuracy: 0.8317
# Epoch 149/150
# 510/510 [==============================] - 81s 158ms/step - loss: 0.8729 - accuracy: 0.8332
# Epoch 150/150
# 510/510 [==============================] - 81s 159ms/step - loss: 0.8662 - accuracy: 0.8340

# %% [markdown]
# # Predict

# %%
model = load_model('english_lstm.h5')

# %%
seed_text = "the world seems so bright so good then go there then not  wid my free kerrigan stole be grieve and relations he said you so then it return a handsome rover one "
next_words = 20
ouptut_text = ""
 
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences(
        [token_list], maxlen=max_sequence_len-1,
      padding='pre')
    predicted = np.argmax(model.predict(token_list, 
                                        verbose=0), axis=-1)
    output_word = ""
     
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
             
    seed_text += " " + output_word
     
print(seed_text)
# Out:
# the world seems so bright so good then go there then not  wid my free kerrigan stole be grieve and relations he said you so then it return a handsome rover one  gay for the fire of spancil hill and sand in spancil brightly too late too late are they say true
